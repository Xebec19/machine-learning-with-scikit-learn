# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
dates = pd.date_range(start="2022-01-01", periods=100,freq="D")

data = pd.DataFrame({
    "date": dates,
    "value": 0.5 * np.arange(100) + np.random.normal(0,5,100)
})

data.head()
# Out:
#         date     value
# 0 2022-01-01 -0.295282
# 1 2022-01-02  6.232993
# 2 2022-01-03 -1.524893
# 3 2022-01-04  0.957806
# 4 2022-01-05  1.648792

# %%
data["lag_1"] = data["value"].shift(1)
data["lag_2"] = data["value"].shift(2)

data.dropna(inplace=True)

# %%
X = data[["lag_1","lag_2"]]
y = data["value"]

split_idx = int(len(data) * 0.8)

X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"MSE: {mse:.f}")
# Out:
# array([35.00848544, 33.53442495, 36.38559412, 39.57155133, 41.52793837,
#        42.57198956, 41.97662405, 43.10361978, 42.2537331 , 43.20791806,
#        43.0515086 , 39.04254706, 41.40354158, 43.79717365, 42.81298766,
#        49.9129501 , 50.88680281, 45.61987972, 42.07371112, 43.37618015])
